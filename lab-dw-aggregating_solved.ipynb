# %% [markdown]
# # Lab | Data Aggregation and Filtering

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company. We will use the dataset called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by first performing data cleaning, formatting, and structuring.

# %% [markdown]
# 1. Create a new DataFrame that only includes customers who have a total_claim_amount greater than $1,000 and have a response of "Yes" to the last marketing campaign.

# %% [markdown]
# 2. Using the original Dataframe, analyze the average total_claim_amount by each policy type and gender for customers who have responded "Yes" to the last marketing campaign. Write your conclusions.

# %% [markdown]
# 3. Analyze the total number of customers who have policies in each state, and then filter the results to only include states where there are more than 500 customers.

# %% [markdown]
# 4. Find the maximum, minimum, and median customer lifetime value by education level and gender. Write your conclusions.

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv"
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                          0
# Customer                            0
# State                             631
# Customer Lifetime Value             0
# Response                          631
# Coverage                            0
# Education                           0
# Effective To Date                   0
# EmploymentStatus                    0
# Gender                              0
# Income                              0
# Location Code                       0
# Marital Status                      0
# Monthly Premium Auto                0
# Months Since Last Claim           633
# Months Since Policy Inception       0
# Number of Open Complaints         633
# Number of Policies                  0
# Policy Type                         0
# Policy                              0
# Renew Offer Type                    0
# Sales Channel                       0
# Total Claim Amount                  0
# Vehicle Class                     622
# Vehicle Size                      622
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                         int64
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim          float64
# Months Since Policy Inception      int64
# Number of Open Complaints        float64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# ...

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type'],
#       dtype='object')

# %%
#Datacleaning
df.columns = df.columns.str.lower().str.replace(' ', '_')
df.drop(columns=['unnamed:_0'], inplace=True)
df['gender'] = df['gender'].replace({'female': 'F', 'Femal': 'F', 'F': 'F','Male': 'M', 'M': 'M'})
df['state'] = df['state'].replace({'AZ': 'Arizona', 'Cali': 'California', 'WA': 'Washington', 'NV': 'Nevada','OR': 'Oregon'})
df['education'] = df['education'].replace('Bachelors', 'Bachelor')
df['customer_lifetime_value'] = df['customer_lifetime_value'].astype(str).str.replace('%', '').astype(float)
df['vehicle_class'] = df['vehicle_class'].replace({'Sports Car': 'Luxury', 'Luxury SUV': 'Luxury', 'Luxury Car': 'Luxury'})
df['number_of_open_complaints'] = df['number_of_open_complaints'].astype(str).str.split('/').str[1]
#rounding all numercial type daat
df[df.select_dtypes(include=['float64', 'int64']).columns] = df.select_dtypes(include=['float64', 'int64',]).round(2)
#dropping Nan rows and repeats
df.dropna(how="all",inplace=True)
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona                  4809.22       No     Basic
# 1      KX64629  California                  2228.53       No     Basic
# 2      LZ68649  Washington                 14947.92       No     Basic
# 3      XL78013      Oregon                 22332.44      Yes  Extended
# 4      QA50777      Oregon                  9025.07       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada                 15563.37       No   Premium
# 10906  KX53892      Oregon                  5259.44       No     Basic
# 10907  TL39050     Arizona                 23893.30       No  Extended
# 10908  WA60547  California                 11971.98       No   Premium
# 10909  IV32877         NaN                  6857.52      NaN     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
df.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona                  4809.22       No     Basic   College
# 1  KX64629  California                  2228.53       No     Basic   College
# 2  LZ68649  Washington                 14947.92       No     Basic  Bachelor
# 3  XL78013      Oregon                 22332.44      Yes  Extended   College
# 4  QA50777      Oregon                  9025.07       No   Premium  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0           2/18/11         Employed      M   48029  ...
# 1           1/18/11       Unemployed      F       0  ...
# 2           2/10/11         Employed      M   22139  ...
# 3           1/11/11         Employed      M   49078  ...
# 4           1/17/11    Medical Leave      F   23675  ...
#
#   number_of_open_complaints number_of_policies     policy_type        policy  \
# 0                       NaN                  9  Corporate Auto  Corporate L3
# ...

# %%
df.shape
# Out:
# (10910, 25)

# %% [markdown]
# #filling Nan values

# %%
df['state'].value_counts()
# Out:
# state
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# Name: count, dtype: int64

# %%
df['vehicle_class'].value_counts()
# Out:
# vehicle_class
# Four-Door Car    5212
# Two-Door Car     2118
# SUV              2012
# Luxury            946
# Name: count, dtype: int64

# %%
df['vehicle_size'].value_counts()
# Out:
# vehicle_size
# Medsize    7251
# Small      1966
# Large      1071
# Name: count, dtype: int64

# %%
df['vehicle_type'].value_counts()
# Out:
# vehicle_type
# A    5428
# Name: count, dtype: int64

# %%
#filling categorical variables with mode 
df['state'] = df['state'].fillna(df['state'].mode()[0])
df['vehicle_class'] = df['vehicle_class'].fillna(df['vehicle_class'].mode()[0])
df['vehicle_size'] = df['vehicle_size'].fillna(df['vehicle_size'].mode()[0])
df['response'] = df['response'].fillna(df['response'].mode()[0])
#vehicle type has one value

# %%
#filling numercial values
df['months_since_last_claim'] = df['months_since_last_claim'].fillna(df['months_since_last_claim'].mean()).round(2)
df['number_of_open_complaints'] = df['number_of_open_complaints'].fillna(df['number_of_open_complaints'].mean()).round(2)

# %%
df.isnull().sum()
# Out:
# customer                             0
# state                                0
# customer_lifetime_value              0
# response                             0
# coverage                             0
# education                            0
# effective_to_date                    0
# employmentstatus                     0
# gender                               0
# income                               0
# location_code                        0
# marital_status                       0
# monthly_premium_auto                 0
# months_since_last_claim              0
# months_since_policy_inception        0
# number_of_open_complaints        10910
# number_of_policies                   0
# policy_type                          0
# policy                               0
# renew_offer_type                     0
# sales_channel                        0
# total_claim_amount                   0
# vehicle_class                        0
# vehicle_size                         0
# ...

# %%
df['number_of_open_complaints'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
#all number_of_open_complaints values are Nan, dropping column
df.drop(columns=['number_of_open_complaints'], inplace=True)

#filling vehicle type with unknown instead of dropping them to save more data for analysing
df['vehicle_type'] = df['vehicle_type'].fillna('unknown')

# %%
df.isnull().sum()
# Out:
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# vehicle_type                     0
# dtype: int64

# %% [markdown]
# #1. Create a new DataFrame that only includes customers who have a total_claim_amount greater than $1,000 and have a response of "Yes" to the last marketing campaign.

# %%
new_df = df[(df['total_claim_amount'] > 1000) & (df['response'] == 'Yes')]
new_df.head(3)
# Out:
#     customer       state  customer_lifetime_value response  coverage  \
# 189  OK31456  California                 11009.13      Yes   Premium
# 236  YJ16163      Oregon                 11009.13      Yes   Premium
# 419  GW43195      Oregon                 25807.06      Yes  Extended
#
#     education effective_to_date employmentstatus gender  income  ...  \
# 189  Bachelor           1/24/11         Employed      F   51643  ...
# 236  Bachelor           1/24/11         Employed      F   51643  ...
# 419   College           2/13/11         Employed      F   71210  ...
#
#     months_since_policy_inception number_of_policies     policy_type  \
# 189                            43                  1  Corporate Auto
# 236                            43                  1    Special Auto
# 419                            89                  2   Personal Auto
#
#            policy  renew_offer_type  sales_channel total_claim_amount  \
# ...

# %% [markdown]
# #2. Using the original Dataframe, analyze the average total_claim_amount by each policy type and gender for customers who have responded "Yes" to the last marketing campaign. Write your conclusions.

# %% [markdown]
# yes_response= df[df['response'] == 'Yes']
# average_total_claim_amount= yes_response.groupby(['policy_type', 'gender'])['total_claim_amount'].mean().round(1)
# average_total_claim_amount

# %% [markdown]
# #3. Analyze the total number of customers who have policies in each state, and then filter the results to only include states where there are more than 500 customers.

# %%
total_number_customers_group= df.groupby(['policy_type', 'state'])['customer'].count()
customer_group=total_number_customers_group[total_number_customers_group>500]
customer_group
# Out:
# policy_type     state
# Corporate Auto  California     974
#                 Oregon         592
# Personal Auto   Arizona       1469
#                 California    3058
#                 Nevada         739
#                 Oregon        2180
#                 Washington     682
# Name: customer, dtype: int64

# %%
#or another solution
total_customers= df.groupby(['policy_type', 'state']).filter(lambda x: x['customer'].count() > 500)
total_customers.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage  \
# 1  KX64629  California                  2228.53       No     Basic
# 2  LZ68649  Washington                 14947.92       No     Basic
# 3  XL78013      Oregon                 22332.44      Yes  Extended
# 4  QA50777      Oregon                  9025.07       No   Premium
# 5  HO81102  California                  4745.18       No     Basic
#
#               education effective_to_date employmentstatus gender  income  \
# 1               College           1/18/11       Unemployed      F       0
# 2              Bachelor           2/10/11         Employed      M   22139
# 3               College           1/11/11         Employed      M   49078
# 4              Bachelor           1/17/11    Medical Leave      F   23675
# 5  High School or Below           2/14/11         Employed      M   50549
#
#    ... months_since_policy_inception number_of_policies     policy_type  \
# ...

# %%
#4.Find the maximum, minimum, and median customer lifetime value by education level and gender. Write your conclusions.

# %%
customer_lifetime_value_group= df.groupby(['education','gender'])['customer_lifetime_value'].agg(['mean', 'median', 'count', 'max', 'min']).round(2)
customer_lifetime_value_group
# Out:
#                                 mean   median  count       max      min
# education            gender
# Bachelor             F       7874.27  5640.50   1700  73225.96  1904.00
#                      M       7703.60  5548.03   1572  67907.27  1898.01
# College              F       7748.82  5623.61   1608  61850.19  1898.68
#                      M       8052.46  6005.85   1596  61134.68  1918.12
# Doctor               F       7328.51  5332.46    200  44856.11  2395.57
#                      M       7415.33  5577.67    201  32677.34  2267.60
# High School or Below F       8675.22  6039.56   1590  55277.45  2144.92
#                      M       8149.69  6286.74   1556  83325.38  1940.98
# Master               F       8157.05  5729.86    475  51016.07  2417.78
#                      M       8168.83  5579.10    412  50568.26  2272.31

# %% [markdown]
# Men with highschool education have the highest median and max livinig longer
# male have the higher median compared to female across all category except from Master eduction
# While the highest life time is for highschool male, the lowest lifetime is for male with bachelor education.
# customers with lower education levels (those with High School), tend to have the highest average customer lifetime value.
